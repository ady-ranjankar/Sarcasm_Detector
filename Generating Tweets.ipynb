# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import tweepy

# %%
CONSUMER_KEY = ""
CONSUMER_SECRET = ""
OAUTH_TOKEN = ""
OAUTH_TOKEN_SECRET = ""
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
api = tweepy.API(auth)

tweet = api.get_status(241501498293485568)
print(tweet.text)
# Out:
# This totally topped off my week :') #sarcasm

# %%
import pandas
dataframe = pandas.read_csv("Tweets.tsv", sep='\t')
data1 = dataframe.values

# %%
j=[]
k=[]
for i in range(0,2999):
    try:
        tweet = api.get_status(data1[i][0])
        j.append(tweet.text)
        j.append(data1[i][1])
        k.append(j)
        j=[]
    except:
        print()

# %%
import numpy as np
k=np.asarray(k)

# %%
import pandas as pd
df = pd.DataFrame(np.transpose(k)).T
df.to_excel(excel_writer = "C:/Users/adity/Desktop/Sem 8/NLP Proj/Dataset.xlsx")
